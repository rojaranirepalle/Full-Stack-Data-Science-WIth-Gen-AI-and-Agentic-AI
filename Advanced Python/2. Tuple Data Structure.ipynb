# %% [markdown]
# # 📦 Python Tuples
#
# A **tuple** is a built-in data structure used to store an ordered collection of items.
#
# Tuples are similar to lists, but they are **immutable**, meaning their values cannot be changed after creation.
#
# ---
#
# # 🔹 Creating a Tuple
#
# ```python
# my_tuple = (1, 2, 3)

# %% [markdown]
# <table style="width:85%; font-size:14px; border-collapse:collapse; margin:auto;"> <thead> <tr style="background-color:#f2f2f2;"> <th style="color:purple; border:1px solid #333; padding:10px;">Characteristic</th> <th style="color:purple; border:1px solid #333; padding:10px;">Description</th> </tr> </thead> <tbody> <tr> <td style="border:1px solid #333; padding:8px;"><b>Immutable</b></td> <td style="border:1px solid #333; padding:8px;"> Tuple items cannot be modified after creation </td> </tr> <tr> <td style="border:1px solid #333; padding:8px;"><b>Ordered</b></td> <td style="border:1px solid #333; padding:8px;"> Maintains insertion order </td> </tr> <tr> <td style="border:1px solid #333; padding:8px;"><b>Allows Duplicates</b></td> <td style="border:1px solid #333; padding:8px;"> Duplicate values are allowed </td> </tr> <tr> <td style="border:1px solid #333; padding:8px;"><b>Index-based</b></td> <td style="border:1px solid #333; padding:8px;"> Elements are accessed using indexes </td> </tr> </tbody> </table>

# %% [markdown]
# <b>Single-Element Tuples Need a Comma:</b> To create a tuple with only one item, you must include a trailing comma (e.g., my_tuple = (1,)). Without it, Python will just see the value inside the parentheses.

# %%
# Tuple declarations
t = ()
print(type(t))
# Out:
# <class 'tuple'>

# %%
# Mixed data types
t1 = (1,2,3,45.6,67)
t2 = ('Roja',1,2,45.5,56,1+2j,True)
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
# Single-Element Tuples Need a Comma
t3 = (4)
print(type(t3))
t4 = (4,)
print(type(t4))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
# Count() returns number of occurances
t5 = (10,'Roja',45,35,10,23,10,10.45)
print(t5.count(10))

# Get the index of value
print(t5.index(10))
# Out:
# 3
# 0

# %%
# Indexing and slicing
print(t5[3])
print(t5[3:5])
print(t5[3:8])
print(t5[3:8:2])
print(t5[::-1])
# Out:
# 35
# (35, 10)
# (35, 10, 23, 10, 10.45)
# (35, 23, 10.45)
# (10.45, 10, 23, 10, 35, 45, 'Roja', 10)

# %%
# Tuple can't be mutable - Immutable
print(t5[2])
t5[2] = 10
# Out:
# 45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Tuple can't be mutable - Immutable
#       2 print(t5[2])
# ----> 3 t5[2] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1*3  # Repeat 3 times
# Out:
# (1, 2, 3, 45.6, 67, 1, 2, 3, 45.6, 67, 1, 2, 3, 45.6, 67)

# %%
# Tuple membership
print(1 in t1)
# Out:
# True
