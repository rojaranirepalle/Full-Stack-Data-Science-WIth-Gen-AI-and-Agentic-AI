# %%
import os
from dotenv import load_dotenv, find_dotenv
from groq import Groq

load_dotenv(find_dotenv())  # finds GenAI/LLM/.env by searching parent directories

client = Groq()
completion = client.chat.completions.create(
    model="qwen/qwen3.8-27b",
    messages=[
      {
        "role": "user",
        "content": "Number of alphabets in Apple \n"
      }
    ],
    temperature=0.6,
    max_completion_tokens=2048,
    top_p=0.95,
    reasoning_effort="default",
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# To determine the number of alphabets (letters) in the word "Apple", we can simply count each character:
#
# 1. A
# 2. p
# 3. p
# 4. l
# 5. e
#
# There are **5** letters in the word "Apple".
