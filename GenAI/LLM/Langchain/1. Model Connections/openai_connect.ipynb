# %%
import openai
import langchain

print("OpenAI version:", openai.__version__)
print("LangChain version:", langchain.__version__)
# Out:
# OpenAI version: 3.8.0
# LangChain version: 1.4.0

# %%
import os
from dotenv import load_dotenv,find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key = os.getenv("TEST_OPENAI_API_KEY")

print("OpenAI API Key:", openai.api_key)
# Out:
# OpenAI API Key: voc-1092981866112272493400369c138d8e94058.98686841

# %%
# create a simple text generation prompt and get a response from the OpenAI API
# Model,Prompt, Memory and Chain configuration

from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

#configure the LLM Model and chain
llm = init_chat_model(model_name="gpt-3.5-turbo", temperature=0.7,max_tokens=200)
prompt = PromptTemplate(input_variables=["topic"], template="Write a short poem about {topic}.")
chain = LLMChain(llm=llm, prompt=prompt) 
response = chain.run("Generative AI")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 5
#       1 # create a simple text generation prompt and get a response from the OpenAI API
#       2 # Model,Prompt, Memory and Chain configuration
#       3
#       4 from langchain.chat_models import init_chat_model
# ----> 5 from langchain.prompts import PromptTemplate
#       6 from langchain.chains import LLMChain
#       7
#       8 #configure the LLM Model and chain
#
# ModuleNotFoundError: No module named 'langchain.prompts'

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import PromptTemplate

# Configure the LLM
llm = init_chat_model(
    model="gpt-3.5-turbo",
    model_provider="openai",
    temperature=0.7,
    max_tokens=200
)

# Create the prompt
prompt = PromptTemplate(
    input_variables=["topic"],
    template="Write a short poem about {topic}."
)

# Modern LangChain chain
chain = prompt | llm

# Invoke the chain
response = chain.invoke({"topic": "Generative AI"})

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1904, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1903 else:
# -> 1904     raw_response = self.client.with_raw_response.create(**payload)
#    1905     response = raw_response.parse()
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# ...
