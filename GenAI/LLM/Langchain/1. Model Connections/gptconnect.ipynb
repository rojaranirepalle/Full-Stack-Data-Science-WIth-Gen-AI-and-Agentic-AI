# %%
# !pip install -U "langchain[openai]"
# Out:
# 443679.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: langchain[openai] in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (1.4.0)
# Collecting langchain[openai]
#   Downloading langchain-1.4.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.3 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain[openai]) (1.6.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain[openai]) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain[openai]) (2.13.5)
# Requirement already satisfied: langchain-openai in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain[openai]) (1.6.2)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.12.4)
# Requirement already satisfied: packaging>=23.2.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.17.1)
# Requirement already satisfied: anyio in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (4.15.1)
# Requirement already satisfied: certifi in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (1.0.9)
# Requirement already satisfied: idna in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain[openai]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain[openai]) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain[openai]) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain[openai]) (2.7.0)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-openai->langchain[openai]) (3.8.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from langchain-openai->langchain[openai]) (0.14.0)
# Requirement already satisfied: jiter<1,>=0.16.0 in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai->langchain[openai]) (0.16.0)
# Requirement already satisfied: regex in /Users/rojarani/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai]) (2026.9.10)
# Downloading langchain-1.4.2-py3-none-any.whl (163 kB)
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.4.0
#     Uninstalling langchain-1.4.0:
#       Successfully uninstalled langchain-1.4.0
# Successfully installed langchain-1.4.2

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# %%
_ = os.getenv("OPENAI_API_KEY")
model_reasoning = init_chat_model(
    model="gpt-3.5-turbo", 
    model_provider="openai",
    temperature=0.7
)
response = model_reasoning.invoke("Hello, how are you?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1904, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1903 else:
# -> 1904     raw_response = self.client.with_raw_response.create(**payload)
#    1905     response = raw_response.parse()
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1295 validate_response_format(response_format)
# -> 1296 return self._post(
#    1297     "/chat/completions",
#    1298     body=maybe_transform(
#    1299         {
#    1300             "messages": messages,
#    1301             "model": model,
#    1302             "audio": audio,
#    1303             "frequency_penalty": frequency_penalty,
#    1304             "function_call": function_call,
#    1305             "functions": functions,
#    1306             "logit_bias": logit_bias,
#    1307             "logprobs": logprobs,
#    1308             "max_completion_tokens": max_completion_tokens,
#    1309             "max_tokens": max_tokens,
#    1310             "metadata": metadata,
#    1311             "modalities": modalities,
#    1312             "moderation": moderation,
#    1313             "n": n,
#    1314             "parallel_tool_calls": parallel_tool_calls,
#    1315             "prediction": prediction,
#    1316             "presence_penalty": presence_penalty,
#    1317             "prompt_cache_key": prompt_cache_key,
#    1318             "prompt_cache_options": prompt_cache_options,
#    1319             "prompt_cache_retention": prompt_cache_retention,
#    1320             "reasoning_effort": reasoning_effort,
#    1321             "response_format": response_format,
#    1322             "safety_identifier": safety_identifier,
#    1323             "seed": seed,
#    1324             "service_tier": service_tier,
#    1325             "stop": stop,
#    1326             "store": store,
#    1327             "stream": stream,
#    1328             "stream_options": stream_options,
#    1329             "temperature": temperature,
#    1330             "tool_choice": tool_choice,
#    1331             "tools": tools,
#    1332             "top_logprobs": top_logprobs,
#    1333             "top_p": top_p,
#    1334             "user": user,
#    1335             "verbosity": verbosity,
#    1336             "web_search_options": web_search_options,
#    1337         },
#    1338         completion_create_params.CompletionCreateParamsStreaming
#    1339         if stream
#    1340         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341     ),
#    1342     options=make_request_options(
#    1343         extra_headers=extra_headers,
#    1344         extra_query=extra_query,
#    1345         extra_body=extra_body,
#    1346         timeout=timeout,
#    1347         security={"bearer_auth": True},
#    1348     ),
#    1349     cast_to=ChatCompletion,
#    1350     stream=stream or False,
#    1351     stream_cls=Stream[ChatCompletionChunk],
#    1352 )
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/openai/_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/openai/_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1140     log.debug("Re-raising status error")
# -> 1141     raise self._make_status_error_from_response(err.response) from None
#    1143 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
#
# The above exception was the direct cause of the following exception:
#
# OpenAIRateLimitError                      Traceback (most recent call last)
# Cell In[35], line 7
#       3     model="gpt-3.5-turbo",
#       4     model_provider="openai",
#       5     temperature=0.7
#       6 )
# ----> 7 response = model_reasoning.invoke("Hello, how are you?")
#       8 print(response.content)
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1909, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1907     _handle_openai_bad_request(e)
#    1908 except openai.APIError as e:
# -> 1909     _handle_openai_api_error(e)
#    1910 except Exception as e:
#    1911     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:668, in _handle_openai_api_error(e)
#     664     raise OpenAIModelNotFoundError(
#     665         message=e.message, response=e.response, body=e.body
#     666     ) from e
#     667 if isinstance(e, openai.RateLimitError):
# --> 668     raise OpenAIRateLimitError(
#     669         message=e.message, response=e.response, body=e.body
#     670     ) from e
#     671 if isinstance(e, openai.InternalServerError):
#     672     raise OpenAIAPIError(message=e.message, response=e.response, body=e.body) from e
#
# OpenAIRateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
