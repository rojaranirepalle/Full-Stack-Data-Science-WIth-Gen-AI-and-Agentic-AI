# %%
#!pip install groq

# %%
import os
from dotenv import load_dotenv, find_dotenv
from groq import Groq

load_dotenv(find_dotenv())  # finds GenAI/LLM/.env by searching parent directories

client = Groq()
completion = client.chat.completions.create(
    model="meta-llama/llama-prompt-guard-2-22m",
    messages=[
      {
        "role": "user",
        "content": "What is the capital of France?"
      }
    ],
    temperature=1,
    max_completion_tokens=1,
    top_p=1,
    stream=False,
    stop=None
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='0.0005918022943660617', role='assistant', annotations=None, executed_tools=None, function_call=None, reasoning=None, tool_calls=None)
