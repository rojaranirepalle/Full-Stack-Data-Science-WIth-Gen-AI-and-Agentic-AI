# %%
#pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
genai.configure(api_key=os.environ.get("GEMINI_API_KEY"))

# %%
model = genai.GenerativeModel("gemini-3.6-flash")
#model = genai.GenerativeModel("gemini-3-flash-preview")

response = model.generate_content("Write a short poem about the beauty of nature.")
print(response.text)
# Out:
# Golden light on mountain peaks,
# A silent tongue that nature speaks.
# The forest breathes in shades of jade,
# In every leaf and grassy blade.
#
# A river hums a silver tune
# Beneath the glow of pearly moon.
# From soaring wing to rooting seed,
# The earth provides all that we need.
