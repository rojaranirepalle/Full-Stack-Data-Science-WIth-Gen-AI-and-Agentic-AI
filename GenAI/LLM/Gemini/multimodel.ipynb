# %%
import PIL.Image

img = PIL.Image.open("Sad_Face_Emoji_large.webp")
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import PIL.Image
#       2
# ----> 3 img = PIL.Image.open("Sad_Face_Emoji_large.webp")
#       4 img
#
# File ~/Documents/AIML/GitAIML/Full-Stack-Data-Science-WIth-Gen-AI-and-Agentic-AI/.venv-tf/lib/python3.11/site-packages/PIL/Image.py:3639, in open(fp, mode, formats)
#    3637 if is_path(fp):
#    3638     filename = os.fspath(fp)
# -> 3639     fp = builtins.open(filename, "rb")
#    3640     exclusive_fp = True
#    3641 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Sad_Face_Emoji_large.webp'
